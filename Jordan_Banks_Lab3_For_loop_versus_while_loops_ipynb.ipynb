# %% [markdown]
# <a href="https://colab.research.google.com/github/BanksBytes/GoogleCollab/blob/main/Jordan_Banks_Lab3_For_loop_versus_while_loops_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color="red">Important!</font>: As usual, make a copy of this notebook, put your name on the title, and share it with okeonwuka@gmail.com
#
# <font color="red"> For example, if your name is Mary Jane, you would make a copy of this notebook and change the title of your copy to "Mary_Jane_Lab3-For_loop versus while loops"</font>

# %% [markdown]
# # **Introduction**

# %% [markdown]
# ### Both **for loops** and **while loops** are used to **execute a block of code multiple times**, but they are used in slightly different scenarios based on the nature of the condition that controls the loop

# %% [markdown]
# #  **1. For Loops!**

# %% [markdown]
# ### Use a ***for loop when you know in advance how many times you need to execute the loop***. This is common in cases where you iterate over a sequence (like a list, tuple, or string) or when you want to run a loop a specific number of times. for loops are typically used for iterating over elements of a collection (e.g., each item in a list) or for running a loop a known number of times because the range is specified
#
# ### Example uses:
# ###- Iterating through elements in a list, tuple, or string.
# ###- Running a loop a fixed number of times using a range.

# %% [markdown]
# ## **Example of using For loops**

# %% [markdown]
# ### Run the following examples:

# %%
# Iterating over a list
for item in [1, 2, 3, 4, 5]:
    print(item)

# %%
# Running a loop a fixed number of times
for i in range(0,5): # 0 to 4
    print(i)

# %% [markdown]
# ##  **Exercise: Sum of Even Numbers**

# %% [markdown]
# ## 1. Write a Python program using a for loop that calculates the sum of all even numbers from 1 to 10, inclusive. Output the result.

# %%
# Write your code here (use as many lines of code as you need)


total = 0
for num in range(1, 11):
    if num % 2 == 0:
        total += num

print("Sum of even numbers from 1 to 10:", total)
# Out:
# Sum of even numbers from 1 to 10: 30

# %% [markdown]
# ##2. Now make the code you wrote above an interactive program, where the program asks the user to input a lower bound number of their choice (e.g 1), and an upper bound number of their choice (e.g 100), and your program prints out the sum of the even numbers between these 2 bounds (upper bound included)

# %%
# Write your code here (use as many lines of code as you need)

total = 0

x = int(input("Enter your lower number:" ))
y = int(input("Enter your upper number:" ))

for num in range (x, y):
  if num % 2 == 0:
    total += num

print(f"Sum of even numbers from {x} to {y}:", total)
# Out:
# Enter your lower number:8
# Enter your upper number:12
# Sum of even numbers from 8 to 12: 18

# %% [markdown]
# #  **2. While Loops!**

# %% [markdown]
# ### Use a ***while loop when the number of times the loop needs to execute is not known in advance and depends on some condition being true***. It's more flexible in terms of controlling the loop since the condition can be based on dynamic data that changes as the loop executes. while loops are typically used for repeating a block of code as long as a certain condition remains true.
#
# ### Example uses:
# ### - Waiting for a specific condition to become False.
# ### - Running a loop until an external condition is met (e.g., user input, file content)

# %% [markdown]
# ## **Example of using while loops**

# %% [markdown]
# ### Run the following examples:

# %%
# Looping until a condition is met
count = 0
while count < 5:
    print(count)
    count += 1  # Important to modify the condition variable within the loop
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ##  **Exercise: Guess the number!**

# %% [markdown]
# ## Implement a game using a while loop where the program generates a random number between 1 and 100, and the user has to guess it. The program should give feedback ('too high', 'too low') until the user guesses the number correctly.

# %%
# # Write your code here (use as many lines of code as you need)
import random

random_number = random.randint(1, 100)
guess_number = 0


while guess_number != random_number:
    guess = int(input("Enter your guess: "))

    if guess < random_number:
        print("Too low!")
    elif guess > random_number:
        print("Too high!")
    else:
        print("Congratulations! You guessed it right!")

        break
# Out:
# Enter your guess: 88
# Too high!
# Enter your guess: 44
# Too high!
# Enter your guess: 22
# Too low!
# Enter your guess: 33
# Congratulations! You guessed it right!
