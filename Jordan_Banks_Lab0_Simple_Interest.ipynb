# %% [markdown]
# <a href="https://colab.research.google.com/github/BanksBytes/GoogleCollab/blob/main/Jordan_Banks_Lab0_Simple_Interest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color="red">Important!</font>: As usual, make a copy of this notebook, put your name on the title, and share it with okeonwuka@gmail.com
#
# <font color="red"> For example, if your name is Mary Jane, you would make a copy of this notebook and change the title of your copy to "Mary_Jane_LabX- XXXXXXX"</font>

# %% [markdown]
# # **Our first Program: Simple Interest! 💵 😁**

# %% [markdown]
# ![DALL·E 2024-06-02 22.03.07 - A visual representation of simple interest in finance, showing a stack of coins growing over time. The background features a timeline with three point.webp](data:image/webp;base64,...)

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# ### In finance, the **Simple Interest, S.I**, made on any money that is a person borrows from a bank is calculated as:
# ### P x R x T,
# ### where:
# ### **P** = Principle in dollars $,
# ### **R** = Rate in percent,
# ### **T** = Time in years.
#
# ### We're going to design a program that calculates the **Simple Interest, S.I**. Then you can use it to collect interest from the money you borrow to your friends!
#
#
#
#
#
# ### Run the cell below

# %%
# Simple interest calculator

# Run the code below
P = int(input('Enter the principle, P: '))
R = int(input('Enter the Rate, R: '))/100
T = int(input('Enter the time, T in years: '))

# Calculate the simple interest
SI = P*R*T
print('The simple interest for Principle P =',P, 'and Rate R=',R,'Time T = ',T,'is: $',SI)

# %% [markdown]
# ## **Now, Your turn!**

# %%
# Simple interest calculator

# Run the code below
P = int(input('Enter the principle, P: '))
R = int(input('Enter the Rate, R: '))/100
T = int(input('Enter the time, T in years: '))

# Calculate the simple interest
SI = P*R*T
print('The simple interest for Principle P =',P, 'and Rate R=',R,'Time T = ',T,'is: $',SI)
# Out:
# Enter the principle, P: 3207
# Enter the Rate, R: 9
# Enter the time, T in years: 1
# The simple interest for Principle P = 3207 and Rate R= 0.09 Time T =  1 is: $ 288.63

# %%
# Simple interest calculator

# Run the code below
P = int(input('Enter the principle, P: '))
R = int(input('Enter the Rate, R: '))/100
T = int(input('Enter the time, T in years: '))

# Calculate the simple interest
SI = P*R*T
print('The simple interest for Principle P =',P, 'and Rate R=',R,'Time T = ',T,'is: $',SI)
# Out:
# Enter the principle, P: 6404
# Enter the Rate, R: 23
# Enter the time, T in years: 3
# The simple interest for Principle P = 6404 and Rate R= 0.23 Time T =  3 is: $ 4418.76

# %%
# Simple interest calculator

# Run the code below
P = int(input('Enter the principle, P: '))
R = int(input('Enter the Rate, R: '))/100
T = int(input('Enter the time, T in years: '))

# Calculate the simple interest
SI = P*R*T
print('The simple interest for Principle P =',P, 'and Rate R=',R,'Time T = ',T,'is: $',SI)
# Out:
# Enter the principle, P: 7738
# Enter the Rate, R: 1
# Enter the time, T in years: 30
# The simple interest for Principle P = 7738 and Rate R= 0.01 Time T =  30 is: $ 2321.3999999999996

# %%
# Simple interest calculator

# Run the code below
P = int(input('Enter the principle, P: '))
R = int(input('Enter the Rate, R: '))/100
T = int(input('Enter the time, T in years: '))

# Calculate the simple interest
SI = P*R*T
print('The simple interest for Principle P =',P, 'and Rate R=',R,'Time T = ',T,'is: $',SI)
# Out:
# Enter the principle, P: 8486
# Enter the Rate, R: 4
# Enter the time, T in years: 15
# The simple interest for Principle P = 8486 and Rate R= 0.04 Time T =  15 is: $ 5091.6

# %%
# Simple interest calculator

# Run the code below
P = int(input('Enter the principle, P: '))
R = int(input('Enter the Rate, R: '))/100
T = int(input('Enter the time, T in years: '))

# Calculate the simple interest
SI = P*R*T
print('The simple interest for Principle P =',P, 'and Rate R=',R,'Time T = ',T,'is: $',SI)
# Out:
# Enter the principle, P: 4126
# Enter the Rate, R: 30
# Enter the time, T in years: 0
# The simple interest for Principle P = 4126 and Rate R= 0.3 Time T =  0 is: $ 0.0

# %%
# Simple interest calculator

# Run the code below
P = int(input('Enter the principle, P: '))
R = int(input('Enter the Rate, R: '))/100
T = int(input('Enter the time, T in years: '))

# Calculate the simple interest
SI = P*R*T
print('The simple interest for Principle P =',P, 'and Rate R=',R,'Time T = ',T,'is: $',SI)
# Out:
# Enter the principle, P: 3135
# Enter the Rate, R: 0
# Enter the time, T in years: 4
# The simple interest for Principle P = 3135 and Rate R= 0.0 Time T =  4 is: $ 0.0

# %% [markdown]
# ### **Calculate the simple interest, S.I, given the following values of P, R and T**
#
# ### 1. P = 3207, R = 9%,  T = 1 years
# ### 2. P = 6404, R = 23%, T = 3 years
# ### 3. P = 7738, R = 1%,  T = 30 years
# ### 4. P = 8486, R = 4%,  T = 15 years
# ### 5. P = 4126, R = 30%, T = 0 years
# ### 6. P = 3135, R = 0%,  T = 4 years
# <br>
#
# ### **To do this, do the following steps:**
# ### 1. Create a new code cell.
# ### 2. Copy the simple interest program into the cell.
# ### 3. Chose any set of P, R, T from 1 - 6 above and run the program with your chosen values.
# ### 4. Repeat steps 1 to 3 for **two** more sets of P,R,T.
# <br>
#
# ### Submit the url of this notebook to canvas.
